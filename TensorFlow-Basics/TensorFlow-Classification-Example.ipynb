# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\SOROOS~1\AppData\Local\Temp\tmp75003yis
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\SOROOS~1\\AppData\\Local\\Temp\\tmp75003yis', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000014C070012B0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From C:\Users\Soroosh-PC\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From C:\Users\Soroosh-PC\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\Users\Soroosh-PC\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\training\monitored_session.py:804: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\SOROOS~1\AppData\Local\Temp\tmp75003yis\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 236.397
# INFO:tensorflow:loss = 4.6742587, step = 101 (0.408 sec)
# INFO:tensorflow:global_step/sec: 323.814
# INFO:tensorflow:loss = 5.6938705, step = 201 (0.309 sec)
# INFO:tensorflow:global_step/sec: 389.328
# INFO:tensorflow:loss = 5.5876007, step = 301 (0.256 sec)
# INFO:tensorflow:global_step/sec: 416.906
# INFO:tensorflow:loss = 3.5364254, step = 401 (0.242 sec)
# INFO:tensorflow:global_step/sec: 420.41
# INFO:tensorflow:loss = 6.7501917, step = 501 (0.239 sec)
# INFO:tensorflow:global_step/sec: 436.931
# INFO:tensorflow:loss = 3.1107657, step = 601 (0.228 sec)
# INFO:tensorflow:global_step/sec: 427.595
# INFO:tensorflow:loss = 7.6892476, step = 701 (0.234 sec)
# INFO:tensorflow:global_step/sec: 408.398
# INFO:tensorflow:loss = 5.35174, step = 801 (0.243 sec)
# INFO:tensorflow:global_step/sec: 395.484
# INFO:tensorflow:loss = 8.3668785, step = 901 (0.252 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\SOROOS~1\AppData\Local\Temp\tmp75003yis\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.9672575.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-21-18:20:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\SOROOS~1\AppData\Local\Temp\tmp75003yis\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-21-18:20:44
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72440946, accuracy_baseline = 0.65748036, auc = 0.78656477, auc_precision_recall = 0.6272227, average_loss = 0.5332901, global_step = 1000, label/mean = 0.34251967, loss = 5.209834, precision = 0.6103896, prediction/mean = 0.36653975, recall = 0.54022986
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\SOROOS~1\AppData\Local\Temp\tmp75003yis\model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.78656477,
#  'auc_precision_recall': 0.6272227,
#  'average_loss': 0.5332901,
#  'label/mean': 0.34251967,
#  'loss': 5.209834,
#  'precision': 0.6103896,
#  'prediction/mean': 0.36653975,
#  'recall': 0.54022986,
#  'global_step': 1000}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\SOROOS~1\AppData\Local\Temp\tmp75003yis\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.06864476], dtype=float32),
#   'logistic': array([0.51715446], dtype=float32),
#   'probabilities': array([0.48284554, 0.51715446], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.6115414], dtype=float32),
#   'logistic': array([0.6482923], dtype=float32),
#   'probabilities': array([0.35170767, 0.6482923 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.5888389], dtype=float32),
#   'logistic': array([0.3569013], dtype=float32),
#   'probabilities': array([0.6430987 , 0.35690132], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7335464], dtype=float32),
#   'logistic': array([0.32441697], dtype=float32),
#   'probabilities': array([0.67558306, 0.324417  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7548323], dtype=float32),
#   'logistic': array([0.14743875], dtype=float32),
#   'probabilities': array([0.8525613 , 0.14743875], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.64164984], dtype=float32),
#   'logistic': array([0.65512633], dtype=float32),
#   'probabilities': array([0.3448737 , 0.65512633], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.46237087], dtype=float32),
#   'logistic': array([0.6135765], dtype=float32),
#   'probabilities': array([0.38642356, 0.6135765 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.676633], dtype=float32),
#   'logistic': array([0.3370132], dtype=float32),
#   'probabilities': array([0.6629868 , 0.33701319], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1821574], dtype=float32),
#   'logistic': array([0.2346645], dtype=float32),
#   'probabilities': array([0.7653355 , 0.23466453], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1350918], dtype=float32),
#   'logistic': array([0.24322267], dtype=float32),
#   'probabilities': array([0.75677735, 0.24322265], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8866506], dtype=float32),
#   'logistic': array([0.13162684], dtype=float32),
#   'probabilities': array([0.86837316, 0.13162684], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7076869], dtype=float32),
#   'logistic': array([0.15346397], dtype=float32),
#   'probabilities': array([0.846536  , 0.15346397], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8248124], dtype=float32),
#   'logistic': array([0.30474308], dtype=float32),
#   'probabilities': array([0.69525695, 0.30474308], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.23272598], dtype=float32),
#   'logistic': array([0.55792034], dtype=float32),
#   'probabilities': array([0.44207972, 0.55792034], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.541499], dtype=float32),
#   'logistic': array([0.17631747], dtype=float32),
#   'probabilities': array([0.82368255, 0.17631747], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8794217], dtype=float32),
#   'logistic': array([0.29329765], dtype=float32),
#   'probabilities': array([0.70670235, 0.29329762], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6300552], dtype=float32),
#   'logistic': array([0.34749803], dtype=float32),
#   'probabilities': array([0.65250194, 0.34749803], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8682213], dtype=float32),
#   'logistic': array([0.13374767], dtype=float32),
#   'probabilities': array([0.8662523 , 0.13374767], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5451374], dtype=float32),
#   'logistic': array([0.3669933], dtype=float32),
#   'probabilities': array([0.6330067 , 0.36699328], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8270323], dtype=float32),
#   'logistic': array([0.13859218], dtype=float32),
#   'probabilities': array([0.8614078 , 0.13859218], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3192754], dtype=float32),
#   'logistic': array([0.21093887], dtype=float32),
#   'probabilities': array([0.7890611 , 0.21093889], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.91870815], dtype=float32),
#   'logistic': array([0.2852212], dtype=float32),
#   'probabilities': array([0.7147788, 0.2852212], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.58645463], dtype=float32),
#   'logistic': array([0.64255124], dtype=float32),
#   'probabilities': array([0.35744873, 0.64255124], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3145663], dtype=float32),
#   'logistic': array([0.21172374], dtype=float32),
#   'probabilities': array([0.78827626, 0.21172376], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6379602], dtype=float32),
#   'logistic': array([0.16274281], dtype=float32),
#   'probabilities': array([0.8372572 , 0.16274281], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.1865687], dtype=float32),
#   'logistic': array([0.7661269], dtype=float32),
#   'probabilities': array([0.23387319, 0.7661269 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5313511], dtype=float32),
#   'logistic': array([0.1777961], dtype=float32),
#   'probabilities': array([0.82220393, 0.1777961 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8571726], dtype=float32),
#   'logistic': array([0.29793042], dtype=float32),
#   'probabilities': array([0.7020696, 0.2979304], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1218987], dtype=float32),
#   'logistic': array([0.10698654], dtype=float32),
#   'probabilities': array([0.8930135 , 0.10698655], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.25403273], dtype=float32),
#   'logistic': array([0.5631688], dtype=float32),
#   'probabilities': array([0.43683115, 0.5631688 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.8516471], dtype=float32),
#   'logistic': array([0.94540375], dtype=float32),
#   'probabilities': array([0.05459624, 0.94540375], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.28143406], dtype=float32),
#   'logistic': array([0.43010223], dtype=float32),
#   'probabilities': array([0.5698978 , 0.43010223], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.80794454], dtype=float32),
#   'logistic': array([0.30832866], dtype=float32),
#   'probabilities': array([0.6916713 , 0.30832866], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.28274596], dtype=float32),
#   'logistic': array([0.5702193], dtype=float32),
#   'probabilities': array([0.42978066, 0.5702193 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2329519], dtype=float32),
#   'logistic': array([0.2256652], dtype=float32),
#   'probabilities': array([0.7743348, 0.2256652], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.61275995], dtype=float32),
#   'logistic': array([0.35142988], dtype=float32),
#   'probabilities': array([0.6485701 , 0.35142988], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.01430672], dtype=float32),
#   'logistic': array([0.4964234], dtype=float32),
#   'probabilities': array([0.50357664, 0.4964234 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.55958104], dtype=float32),
#   'logistic': array([0.6363556], dtype=float32),
#   'probabilities': array([0.36364442, 0.6363556 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.0965521], dtype=float32),
#   'logistic': array([0.7496135], dtype=float32),
#   'probabilities': array([0.25038648, 0.7496135 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.61215115], dtype=float32),
#   'logistic': array([0.35156864], dtype=float32),
#   'probabilities': array([0.64843136, 0.35156864], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5321407], dtype=float32),
#   'logistic': array([0.17768069], dtype=float32),
#   'probabilities': array([0.8223193 , 0.17768069], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.3315549], dtype=float32),
#   'logistic': array([0.58213764], dtype=float32),
#   'probabilities': array([0.41786233, 0.58213764], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8302166], dtype=float32),
#   'logistic': array([0.13821247], dtype=float32),
#   'probabilities': array([0.86178756, 0.13821247], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.17275095], dtype=float32),
#   'logistic': array([0.5430807], dtype=float32),
#   'probabilities': array([0.45691937, 0.5430807 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8977833], dtype=float32),
#   'logistic': array([0.13035958], dtype=float32),
#   'probabilities': array([0.8696404 , 0.13035956], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1156907], dtype=float32),
#   'logistic': array([0.10758109], dtype=float32),
#   'probabilities': array([0.89241886, 0.10758109], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.47146618], dtype=float32),
#   'logistic': array([0.6157307], dtype=float32),
#   'probabilities': array([0.38426927, 0.6157307 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4785956], dtype=float32),
#   'logistic': array([0.18563963], dtype=float32),
#   'probabilities': array([0.8143604 , 0.18563965], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4680836], dtype=float32),
#   'logistic': array([0.18723406], dtype=float32),
#   'probabilities': array([0.81276596, 0.18723407], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9923933], dtype=float32),
#   'logistic': array([0.12000389], dtype=float32),
#   'probabilities': array([0.8799961 , 0.12000389], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6147192], dtype=float32),
#   'logistic': array([0.16593446], dtype=float32),
#   'probabilities': array([0.8340656 , 0.16593446], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1472588], dtype=float32),
#   'logistic': array([0.24099013], dtype=float32),
#   'probabilities': array([0.75900984, 0.24099015], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0849729], dtype=float32),
#   'logistic': array([0.2525661], dtype=float32),
#   'probabilities': array([0.74743396, 0.25256613], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.45655787], dtype=float32),
#   'logistic': array([0.3878027], dtype=float32),
#   'probabilities': array([0.61219734, 0.38780275], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9639904], dtype=float32),
#   'logistic': array([0.12303584], dtype=float32),
#   'probabilities': array([0.8769642 , 0.12303585], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2859907], dtype=float32),
#   'logistic': array([0.2165322], dtype=float32),
#   'probabilities': array([0.7834678, 0.2165322], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3750722], dtype=float32),
#   'logistic': array([0.2018016], dtype=float32),
#   'probabilities': array([0.7981984 , 0.20180158], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3494772], dtype=float32),
#   'logistic': array([0.20595585], dtype=float32),
#   'probabilities': array([0.79404414, 0.20595586], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.16939455], dtype=float32),
#   'logistic': array([0.45775232], dtype=float32),
#   'probabilities': array([0.54224765, 0.45775232], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6197746], dtype=float32),
#   'logistic': array([0.16523597], dtype=float32),
#   'probabilities': array([0.834764  , 0.16523595], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1615667], dtype=float32),
#   'logistic': array([0.23838273], dtype=float32),
#   'probabilities': array([0.76161724, 0.23838273], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.47788548], dtype=float32),
#   'logistic': array([0.6172484], dtype=float32),
#   'probabilities': array([0.38275155, 0.6172484 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.49520493], dtype=float32),
#   'logistic': array([0.6213318], dtype=float32),
#   'probabilities': array([0.3786682, 0.6213318], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.056463], dtype=float32),
#   'logistic': array([0.514112], dtype=float32),
#   'probabilities': array([0.48588797, 0.514112  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.6416924], dtype=float32),
#   'logistic': array([0.34486407], dtype=float32),
#   'probabilities': array([0.6551359 , 0.34486407], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.10866326], dtype=float32),
#   'logistic': array([0.4728609], dtype=float32),
#   'probabilities': array([0.5271391, 0.4728609], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.498201], dtype=float32),
#   'logistic': array([0.18269399], dtype=float32),
#   'probabilities': array([0.817306  , 0.18269399], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.466534], dtype=float32),
#   'logistic': array([0.18746999], dtype=float32),
#   'probabilities': array([0.81253004, 0.18747   ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7242538], dtype=float32),
#   'logistic': array([0.15132406], dtype=float32),
#   'probabilities': array([0.8486759 , 0.15132405], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9977816], dtype=float32),
#   'logistic': array([0.11943603], dtype=float32),
#   'probabilities': array([0.880564  , 0.11943603], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.49028826], dtype=float32),
#   'logistic': array([0.6201743], dtype=float32),
#   'probabilities': array([0.37982562, 0.6201743 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2923608], dtype=float32),
#   'logistic': array([0.2154535], dtype=float32),
#   'probabilities': array([0.7845465 , 0.21545349], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.22427016], dtype=float32),
#   'logistic': array([0.44416627], dtype=float32),
#   'probabilities': array([0.5558337 , 0.44416627], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.25703895], dtype=float32),
#   'logistic': array([0.5639083], dtype=float32),
#   'probabilities': array([0.43609175, 0.5639083 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.94178176], dtype=float32),
#   'logistic': array([0.2805406], dtype=float32),
#   'probabilities': array([0.7194595, 0.2805406], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5908258], dtype=float32),
#   'logistic': array([0.64355457], dtype=float32),
#   'probabilities': array([0.3564454 , 0.64355457], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.919371], dtype=float32),
#   'logistic': array([0.12793173], dtype=float32),
#   'probabilities': array([0.8720683 , 0.12793173], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.42822146], dtype=float32),
#   'logistic': array([0.6054489], dtype=float32),
#   'probabilities': array([0.3945511, 0.6054489], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9305978], dtype=float32),
#   'logistic': array([0.12668443], dtype=float32),
#   'probabilities': array([0.8733156 , 0.12668444], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.28417766], dtype=float32),
#   'logistic': array([0.5705702], dtype=float32),
#   'probabilities': array([0.4294299, 0.5705702], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.82357144], dtype=float32),
#   'logistic': array([0.30500606], dtype=float32),
#   'probabilities': array([0.6949939 , 0.30500606], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6907594], dtype=float32),
#   'logistic': array([0.15567599], dtype=float32),
#   'probabilities': array([0.844324, 0.155676], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.20609939], dtype=float32),
#   'logistic': array([0.55134326], dtype=float32),
#   'probabilities': array([0.44865677, 0.55134326], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.4732299], dtype=float32),
#   'logistic': array([0.61614794], dtype=float32),
#   'probabilities': array([0.38385206, 0.61614794], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.16533577], dtype=float32),
#   'logistic': array([0.54124004], dtype=float32),
#   'probabilities': array([0.45875996, 0.54124004], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6418211], dtype=float32),
#   'logistic': array([0.16221741], dtype=float32),
#   'probabilities': array([0.83778256, 0.1622174 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.645112], dtype=float32),
#   'logistic': array([0.3440919], dtype=float32),
#   'probabilities': array([0.6559081 , 0.34409186], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.696104], dtype=float32),
#   'logistic': array([0.15497479], dtype=float32),
#   'probabilities': array([0.84502524, 0.15497479], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7277098], dtype=float32),
#   'logistic': array([0.6743025], dtype=float32),
#   'probabilities': array([0.3256975, 0.6743025], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.3886092], dtype=float32),
#   'logistic': array([0.8003701], dtype=float32),
#   'probabilities': array([0.19962989, 0.8003701 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.42067492], dtype=float32),
#   'logistic': array([0.6036447], dtype=float32),
#   'probabilities': array([0.39635524, 0.6036447 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3270063], dtype=float32),
#   'logistic': array([0.20965499], dtype=float32),
#   'probabilities': array([0.790345  , 0.20965499], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.14595997], dtype=float32),
#   'logistic': array([0.46357468], dtype=float32),
#   'probabilities': array([0.53642535, 0.46357465], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.42046243], dtype=float32),
#   'logistic': array([0.3964061], dtype=float32),
#   'probabilities': array([0.6035939 , 0.39640608], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.2534384], dtype=float32),
#   'logistic': array([0.43697736], dtype=float32),
#   'probabilities': array([0.5630226, 0.4369774], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5346543], dtype=float32),
#   'logistic': array([0.369432], dtype=float32),
#   'probabilities': array([0.630568, 0.369432], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.27979362], dtype=float32),
#   'logistic': array([0.43050435], dtype=float32),
#   'probabilities': array([0.5694956 , 0.43050435], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7737093], dtype=float32),
#   'logistic': array([0.14508164], dtype=float32),
#   'probabilities': array([0.85491836, 0.14508165], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.20986772], dtype=float32),
#   'logistic': array([0.5522752], dtype=float32),
#   'probabilities': array([0.4477248, 0.5522752], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.21591473], dtype=float32),
#   'logistic': array([0.55376995], dtype=float32),
#   'probabilities': array([0.44623005, 0.55376995], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1760485], dtype=float32),
#   'logistic': array([0.23576343], dtype=float32),
#   'probabilities': array([0.7642366 , 0.23576345], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5801193], dtype=float32),
#   'logistic': array([0.1707786], dtype=float32),
#   'probabilities': array([0.8292214 , 0.17077859], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6065943], dtype=float32),
#   'logistic': array([0.16706198], dtype=float32),
#   'probabilities': array([0.832938  , 0.16706198], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9686995], dtype=float32),
#   'logistic': array([0.2751398], dtype=float32),
#   'probabilities': array([0.7248602 , 0.27513978], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.4073937], dtype=float32),
#   'logistic': array([0.39953724], dtype=float32),
#   'probabilities': array([0.6004628 , 0.39953724], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9422555], dtype=float32),
#   'logistic': array([0.12540027], dtype=float32),
#   'probabilities': array([0.87459975, 0.12540029], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.63936615], dtype=float32),
#   'logistic': array([0.34538984], dtype=float32),
#   'probabilities': array([0.65461016, 0.34538984], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2129431], dtype=float32),
#   'logistic': array([0.22918071], dtype=float32),
#   'probabilities': array([0.77081925, 0.22918072], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1733146], dtype=float32),
#   'logistic': array([0.10217258], dtype=float32),
#   'probabilities': array([0.8978274 , 0.10217258], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9322097], dtype=float32),
#   'logistic': array([0.1265062], dtype=float32),
#   'probabilities': array([0.8734938, 0.1265062], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0838864], dtype=float32),
#   'logistic': array([0.74722874], dtype=float32),
#   'probabilities': array([0.25277126, 0.74722874], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.528742], dtype=float32),
#   'logistic': array([0.17817783], dtype=float32),
#   'probabilities': array([0.8218221 , 0.17817782], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9541681], dtype=float32),
#   'logistic': array([0.12409959], dtype=float32),
#   'probabilities': array([0.87590045, 0.12409959], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.773889], dtype=float32),
#   'logistic': array([0.14505936], dtype=float32),
#   'probabilities': array([0.8549406 , 0.14505936], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.09725803], dtype=float32),
#   'logistic': array([0.47570464], dtype=float32),
#   'probabilities': array([0.52429533, 0.4757046 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.10542476], dtype=float32),
#   'logistic': array([0.47366822], dtype=float32),
#   'probabilities': array([0.52633184, 0.47366822], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1882253], dtype=float32),
#   'logistic': array([0.23357649], dtype=float32),
#   'probabilities': array([0.7664235 , 0.23357649], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.17479259], dtype=float32),
#   'logistic': array([0.4564128], dtype=float32),
#   'probabilities': array([0.54358727, 0.4564128 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5926063], dtype=float32),
#   'logistic': array([0.16901752], dtype=float32),
#   'probabilities': array([0.8309825 , 0.16901754], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2565022], dtype=float32),
#   'logistic': array([0.22157662], dtype=float32),
#   'probabilities': array([0.77842337, 0.22157662], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.00652981], dtype=float32),
#   'logistic': array([0.50163245], dtype=float32),
#   'probabilities': array([0.49836755, 0.50163245], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.08978552], dtype=float32),
#   'logistic': array([0.47756866], dtype=float32),
#   'probabilities': array([0.5224313, 0.4775687], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9076092], dtype=float32),
#   'logistic': array([0.12924968], dtype=float32),
#   'probabilities': array([0.8707503 , 0.12924968], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.28895462], dtype=float32),
#   'logistic': array([0.42825982], dtype=float32),
#   'probabilities': array([0.5717402 , 0.42825985], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7777264], dtype=float32),
#   'logistic': array([0.6851899], dtype=float32),
#   'probabilities': array([0.3148101, 0.6851899], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.12596774], dtype=float32),
#   'logistic': array([0.53145033], dtype=float32),
#   'probabilities': array([0.4685496 , 0.53145033], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.45132923], dtype=float32),
#   'logistic': array([0.38904476], dtype=float32),
#   'probabilities': array([0.6109552 , 0.38904473], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.23747814], dtype=float32),
#   'logistic': array([0.5590921], dtype=float32),
#   'probabilities': array([0.44090796, 0.5590921 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2226571], dtype=float32),
#   'logistic': array([0.22746919], dtype=float32),
#   'probabilities': array([0.77253085, 0.2274692 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5071183], dtype=float32),
#   'logistic': array([0.18136624], dtype=float32),
#   'probabilities': array([0.81863374, 0.18136625], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9627609], dtype=float32),
#   'logistic': array([0.12316857], dtype=float32),
#   'probabilities': array([0.8768315 , 0.12316857], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.038058], dtype=float32),
#   'logistic': array([0.2615249], dtype=float32),
#   'probabilities': array([0.73847514, 0.2615249 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.03303349], dtype=float32),
#   'logistic': array([0.5082576], dtype=float32),
#   'probabilities': array([0.4917424, 0.5082576], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.7480017], dtype=float32),
#   'logistic': array([0.6787431], dtype=float32),
#   'probabilities': array([0.32125688, 0.6787431 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2481937], dtype=float32),
#   'logistic': array([0.22301297], dtype=float32),
#   'probabilities': array([0.776987  , 0.22301297], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6293764], dtype=float32),
#   'logistic': array([0.16391581], dtype=float32),
#   'probabilities': array([0.8360842, 0.1639158], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.28994685], dtype=float32),
#   'logistic': array([0.4280169], dtype=float32),
#   'probabilities': array([0.57198316, 0.42801687], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.237388], dtype=float32),
#   'logistic': array([0.22489098], dtype=float32),
#   'probabilities': array([0.775109  , 0.22489096], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7845488], dtype=float32),
#   'logistic': array([0.14374235], dtype=float32),
#   'probabilities': array([0.8562576 , 0.14374235], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4991338], dtype=float32),
#   'logistic': array([0.18255474], dtype=float32),
#   'probabilities': array([0.8174453 , 0.18255475], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9128807], dtype=float32),
#   'logistic': array([0.12865756], dtype=float32),
#   'probabilities': array([0.8713424 , 0.12865756], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5335703], dtype=float32),
#   'logistic': array([0.36968455], dtype=float32),
#   'probabilities': array([0.6303154 , 0.36968455], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.1994631], dtype=float32),
#   'logistic': array([0.7684293], dtype=float32),
#   'probabilities': array([0.23157074, 0.7684293 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.1733139], dtype=float32),
#   'logistic': array([0.7637435], dtype=float32),
#   'probabilities': array([0.23625651, 0.7637435 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.07216275], dtype=float32),
#   'logistic': array([0.5180329], dtype=float32),
#   'probabilities': array([0.48196718, 0.5180329 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.11754596], dtype=float32),
#   'logistic': array([0.5293527], dtype=float32),
#   'probabilities': array([0.47064734, 0.5293527 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.3041718], dtype=float32),
#   'logistic': array([0.57546204], dtype=float32),
#   'probabilities': array([0.42453796, 0.57546204], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.0585537], dtype=float32),
#   'logistic': array([0.11319092], dtype=float32),
#   'probabilities': array([0.88680905, 0.11319093], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.18889976], dtype=float32),
#   'logistic': array([0.54708505], dtype=float32),
#   'probabilities': array([0.452915  , 0.54708505], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.1713133], dtype=float32),
#   'logistic': array([0.7633823], dtype=float32),
#   'probabilities': array([0.2366177, 0.7633823], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.37965822], dtype=float32),
#   'logistic': array([0.40620935], dtype=float32),
#   'probabilities': array([0.59379065, 0.4062093 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1084614], dtype=float32),
#   'logistic': array([0.24815786], dtype=float32),
#   'probabilities': array([0.75184214, 0.24815784], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6846356], dtype=float32),
#   'logistic': array([0.3352275], dtype=float32),
#   'probabilities': array([0.66477257, 0.3352275 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.33121634], dtype=float32),
#   'logistic': array([0.58205533], dtype=float32),
#   'probabilities': array([0.41794473, 0.58205533], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1904546], dtype=float32),
#   'logistic': array([0.23317763], dtype=float32),
#   'probabilities': array([0.76682234, 0.23317763], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.65918803], dtype=float32),
#   'logistic': array([0.65907794], dtype=float32),
#   'probabilities': array([0.340922  , 0.65907794], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.24515814], dtype=float32),
#   'logistic': array([0.4390156], dtype=float32),
#   'probabilities': array([0.5609844, 0.4390156], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.25228965], dtype=float32),
#   'logistic': array([0.43726003], dtype=float32),
#   'probabilities': array([0.56273997, 0.43726   ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6527938], dtype=float32),
#   'logistic': array([0.16073172], dtype=float32),
#   'probabilities': array([0.83926827, 0.16073172], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5849683], dtype=float32),
#   'logistic': array([0.17009299], dtype=float32),
#   'probabilities': array([0.829907, 0.170093], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4766138], dtype=float32),
#   'logistic': array([0.18593945], dtype=float32),
#   'probabilities': array([0.8140606 , 0.18593945], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.259417], dtype=float32),
#   'logistic': array([0.43550706], dtype=float32),
#   'probabilities': array([0.56449294, 0.435507  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7692358], dtype=float32),
#   'logistic': array([0.1456374], dtype=float32),
#   'probabilities': array([0.8543626, 0.1456374], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7985524], dtype=float32),
#   'logistic': array([0.6896647], dtype=float32),
#   'probabilities': array([0.31033525, 0.6896647 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3956307], dtype=float32),
#   'logistic': array([0.19851036], dtype=float32),
#   'probabilities': array([0.80148965, 0.19851038], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.01845676], dtype=float32),
#   'logistic': array([0.49538594], dtype=float32),
#   'probabilities': array([0.50461406, 0.49538594], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7147956], dtype=float32),
#   'logistic': array([0.15254274], dtype=float32),
#   'probabilities': array([0.84745723, 0.15254274], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.63721013], dtype=float32),
#   'logistic': array([0.65412253], dtype=float32),
#   'probabilities': array([0.34587747, 0.65412253], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.8682755], dtype=float32),
#   'logistic': array([0.29561326], dtype=float32),
#   'probabilities': array([0.7043868 , 0.29561326], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4111608], dtype=float32),
#   'logistic': array([0.19605103], dtype=float32),
#   'probabilities': array([0.803949  , 0.19605103], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6314838], dtype=float32),
#   'logistic': array([0.34717417], dtype=float32),
#   'probabilities': array([0.65282583, 0.34717417], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.75245386], dtype=float32),
#   'logistic': array([0.32028684], dtype=float32),
#   'probabilities': array([0.6797132 , 0.32028687], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6227598], dtype=float32),
#   'logistic': array([0.1648246], dtype=float32),
#   'probabilities': array([0.8351754, 0.1648246], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.87813663], dtype=float32),
#   'logistic': array([0.7064359], dtype=float32),
#   'probabilities': array([0.29356405, 0.7064359 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.476829], dtype=float32),
#   'logistic': array([0.18590686], dtype=float32),
#   'probabilities': array([0.8140932 , 0.18590684], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6070657], dtype=float32),
#   'logistic': array([0.1669964], dtype=float32),
#   'probabilities': array([0.83300364, 0.1669964 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8860311], dtype=float32),
#   'logistic': array([0.29192954], dtype=float32),
#   'probabilities': array([0.7080704, 0.2919295], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.27495545], dtype=float32),
#   'logistic': array([0.43169093], dtype=float32),
#   'probabilities': array([0.56830907, 0.43169096], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0962155], dtype=float32),
#   'logistic': array([0.2504497], dtype=float32),
#   'probabilities': array([0.7495504, 0.2504497], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9668262], dtype=float32),
#   'logistic': array([0.12273018], dtype=float32),
#   'probabilities': array([0.8772698 , 0.12273019], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.5873556], dtype=float32),
#   'logistic': array([0.8302437], dtype=float32),
#   'probabilities': array([0.16975626, 0.8302437 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.58819854], dtype=float32),
#   'logistic': array([0.6429517], dtype=float32),
#   'probabilities': array([0.3570483, 0.6429517], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.08079624], dtype=float32),
#   'logistic': array([0.47981194], dtype=float32),
#   'probabilities': array([0.5201881 , 0.47981194], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0101602], dtype=float32),
#   'logistic': array([0.7330515], dtype=float32),
#   'probabilities': array([0.2669485, 0.7330515], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.0325062], dtype=float32),
#   'logistic': array([0.115832], dtype=float32),
#   'probabilities': array([0.884168, 0.115832], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8022029], dtype=float32),
#   'logistic': array([0.14158311], dtype=float32),
#   'probabilities': array([0.8584169 , 0.14158311], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3148377], dtype=float32),
#   'logistic': array([0.21167846], dtype=float32),
#   'probabilities': array([0.7883215 , 0.21167845], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7459549], dtype=float32),
#   'logistic': array([0.32170334], dtype=float32),
#   'probabilities': array([0.6782966 , 0.32170334], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.55884403], dtype=float32),
#   'logistic': array([0.36381495], dtype=float32),
#   'probabilities': array([0.63618505, 0.36381498], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.30031645], dtype=float32),
#   'logistic': array([0.5745199], dtype=float32),
#   'probabilities': array([0.4254801, 0.5745199], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.3115623], dtype=float32),
#   'logistic': array([0.5772666], dtype=float32),
#   'probabilities': array([0.42273343, 0.5772666 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.39006704], dtype=float32),
#   'logistic': array([0.40370116], dtype=float32),
#   'probabilities': array([0.5962988 , 0.40370116], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5669346], dtype=float32),
#   'logistic': array([0.36194447], dtype=float32),
#   'probabilities': array([0.63805556, 0.36194447], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6449045], dtype=float32),
#   'logistic': array([0.3441387], dtype=float32),
#   'probabilities': array([0.65586126, 0.3441387 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4752905], dtype=float32),
#   'logistic': array([0.1861398], dtype=float32),
#   'probabilities': array([0.8138602, 0.1861398], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5851706], dtype=float32),
#   'logistic': array([0.64225626], dtype=float32),
#   'probabilities': array([0.35774368, 0.64225626], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.864793], dtype=float32),
#   'logistic': array([0.13414536], dtype=float32),
#   'probabilities': array([0.8658546 , 0.13414536], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0008174], dtype=float32),
#   'logistic': array([0.26878074], dtype=float32),
#   'probabilities': array([0.73121923, 0.26878074], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.22371185], dtype=float32),
#   'logistic': array([0.55569583], dtype=float32),
#   'probabilities': array([0.4443041 , 0.55569583], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.7148293], dtype=float32),
#   'logistic': array([0.3285326], dtype=float32),
#   'probabilities': array([0.6714674 , 0.32853264], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4532379], dtype=float32),
#   'logistic': array([0.18950376], dtype=float32),
#   'probabilities': array([0.8104963 , 0.18950376], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1022068], dtype=float32),
#   'logistic': array([0.24932662], dtype=float32),
#   'probabilities': array([0.75067335, 0.24932663], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1186008], dtype=float32),
#   'logistic': array([0.24627091], dtype=float32),
#   'probabilities': array([0.75372905, 0.24627088], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8100281], dtype=float32),
#   'logistic': array([0.14063473], dtype=float32),
#   'probabilities': array([0.8593653 , 0.14063473], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4606502], dtype=float32),
#   'logistic': array([0.1883679], dtype=float32),
#   'probabilities': array([0.8116321 , 0.18836789], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.25458634], dtype=float32),
#   'logistic': array([0.563305], dtype=float32),
#   'probabilities': array([0.43669495, 0.563305  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.68530893], dtype=float32),
#   'logistic': array([0.6649226], dtype=float32),
#   'probabilities': array([0.33507743, 0.6649226 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5947727], dtype=float32),
#   'logistic': array([0.6444595], dtype=float32),
#   'probabilities': array([0.35554054, 0.6444595 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.8059974], dtype=float32),
#   'logistic': array([0.69125587], dtype=float32),
#   'probabilities': array([0.30874407, 0.6912559 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.12743378], dtype=float32),
#   'logistic': array([0.46818462], dtype=float32),
#   'probabilities': array([0.5318154 , 0.46818462], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7403922], dtype=float32),
#   'logistic': array([0.3229184], dtype=float32),
#   'probabilities': array([0.67708164, 0.32291842], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.16141045], dtype=float32),
#   'logistic': array([0.5402652], dtype=float32),
#   'probabilities': array([0.45973474, 0.5402652 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.561851], dtype=float32),
#   'logistic': array([0.1733812], dtype=float32),
#   'probabilities': array([0.82661885, 0.17338121], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7431365], dtype=float32),
#   'logistic': array([0.14891498], dtype=float32),
#   'probabilities': array([0.851085  , 0.14891498], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5420499], dtype=float32),
#   'logistic': array([0.17623748], dtype=float32),
#   'probabilities': array([0.82376254, 0.17623748], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.06479526], dtype=float32),
#   'logistic': array([0.51619315], dtype=float32),
#   'probabilities': array([0.48380685, 0.51619315], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.7098508], dtype=float32),
#   'logistic': array([0.06239458], dtype=float32),
#   'probabilities': array([0.93760544, 0.06239459], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9457604], dtype=float32),
#   'logistic': array([0.27973825], dtype=float32),
#   'probabilities': array([0.72026175, 0.27973822], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6372945], dtype=float32),
#   'logistic': array([0.16283354], dtype=float32),
#   'probabilities': array([0.8371665 , 0.16283354], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.90426826], dtype=float32),
#   'logistic': array([0.28817415], dtype=float32),
#   'probabilities': array([0.7118258 , 0.28817415], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2404125], dtype=float32),
#   'logistic': array([0.2243642], dtype=float32),
#   'probabilities': array([0.7756358 , 0.22436419], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9614823], dtype=float32),
#   'logistic': array([0.27658153], dtype=float32),
#   'probabilities': array([0.7234185 , 0.27658153], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2382786], dtype=float32),
#   'logistic': array([0.77526426], dtype=float32),
#   'probabilities': array([0.22473575, 0.77526426], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.630209], dtype=float32),
#   'logistic': array([0.16380173], dtype=float32),
#   'probabilities': array([0.8361983 , 0.16380174], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0342894], dtype=float32),
#   'logistic': array([0.11564951], dtype=float32),
#   'probabilities': array([0.8843505, 0.1156495], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.29238617], dtype=float32),
#   'logistic': array([0.5725802], dtype=float32),
#   'probabilities': array([0.4274198, 0.5725802], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.04320496], dtype=float32),
#   'logistic': array([0.48920047], dtype=float32),
#   'probabilities': array([0.5107996 , 0.48920047], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.7710044], dtype=float32),
#   'logistic': array([0.85458255], dtype=float32),
#   'probabilities': array([0.14541747, 0.85458255], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.69237375], dtype=float32),
#   'logistic': array([0.6664948], dtype=float32),
#   'probabilities': array([0.3335052, 0.6664948], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.039143], dtype=float32),
#   'logistic': array([0.11515401], dtype=float32),
#   'probabilities': array([0.884846  , 0.11515402], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.4666829], dtype=float32),
#   'logistic': array([0.61459833], dtype=float32),
#   'probabilities': array([0.38540164, 0.61459833], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.05096436], dtype=float32),
#   'logistic': array([0.5127383], dtype=float32),
#   'probabilities': array([0.48726162, 0.5127383 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.0469711], dtype=float32),
#   'logistic': array([0.74019283], dtype=float32),
#   'probabilities': array([0.25980717, 0.74019283], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2030677], dtype=float32),
#   'logistic': array([0.23092996], dtype=float32),
#   'probabilities': array([0.7690701 , 0.23092996], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5560536], dtype=float32),
#   'logistic': array([0.17421366], dtype=float32),
#   'probabilities': array([0.82578635, 0.17421365], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.15814543], dtype=float32),
#   'logistic': array([0.53945416], dtype=float32),
#   'probabilities': array([0.46054584, 0.53945416], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7538881], dtype=float32),
#   'logistic': array([0.14755747], dtype=float32),
#   'probabilities': array([0.8524425 , 0.14755747], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2666109], dtype=float32),
#   'logistic': array([0.78016204], dtype=float32),
#   'probabilities': array([0.21983796, 0.78016204], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.16687965], dtype=float32),
#   'logistic': array([0.54162335], dtype=float32),
#   'probabilities': array([0.45837662, 0.54162335], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6509757], dtype=float32),
#   'logistic': array([0.16097713], dtype=float32),
#   'probabilities': array([0.8390229 , 0.16097713], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.08683288], dtype=float32),
#   'logistic': array([0.5216946], dtype=float32),
#   'probabilities': array([0.47830543, 0.5216946 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.05530614], dtype=float32),
#   'logistic': array([0.48617697], dtype=float32),
#   'probabilities': array([0.51382303, 0.486177  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0739956], dtype=float32),
#   'logistic': array([0.11165012], dtype=float32),
#   'probabilities': array([0.8883499 , 0.11165013], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.06448549], dtype=float32),
#   'logistic': array([0.48388422], dtype=float32),
#   'probabilities': array([0.5161158 , 0.48388422], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.42710435], dtype=float32),
#   'logistic': array([0.605182], dtype=float32),
#   'probabilities': array([0.394818, 0.605182], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.9526503], dtype=float32),
#   'logistic': array([0.72164786], dtype=float32),
#   'probabilities': array([0.27835214, 0.72164786], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.3422446], dtype=float32),
#   'logistic': array([0.79285884], dtype=float32),
#   'probabilities': array([0.20714116, 0.79285884], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.19209146], dtype=float32),
#   'logistic': array([0.45212424], dtype=float32),
#   'probabilities': array([0.54787576, 0.45212427], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6911621], dtype=float32),
#   'logistic': array([0.15562308], dtype=float32),
#   'probabilities': array([0.8443769 , 0.15562308], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.4008768], dtype=float32),
#   'logistic': array([0.08310586], dtype=float32),
#   'probabilities': array([0.9168942 , 0.08310587], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1959054], dtype=float32),
#   'logistic': array([0.10011879], dtype=float32),
#   'probabilities': array([0.8998812 , 0.10011878], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0913608], dtype=float32),
#   'logistic': array([0.25136212], dtype=float32),
#   'probabilities': array([0.74863786, 0.25136212], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7529222], dtype=float32),
#   'logistic': array([0.3201849], dtype=float32),
#   'probabilities': array([0.67981505, 0.3201849 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0624743], dtype=float32),
#   'logistic': array([0.25683692], dtype=float32),
#   'probabilities': array([0.7431631 , 0.25683692], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\SOROOS~1\AppData\Local\Temp\tmpvy4y84ba
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\SOROOS~1\\AppData\\Local\\Temp\\tmpvy4y84ba', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000014C09BFB160>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-cea30273f6d4> in <module>
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     352
#     353       saving_listeners = _check_listeners_type(saving_listeners)
# --> 354       loss = self._train_model(input_fn, hooks, saving_listeners)
#     355       logging.info('Loss for final step: %s.', loss)
#     356       return self
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1205       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1206     else:
# -> 1207       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1208
#    1209   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1235       worker_hooks.extend(input_hooks)
#    1236       estimator_spec = self._call_model_fn(
# -> 1237           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#    1238       global_step_tensor = training_util.get_global_step(g)
#    1239       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1193
#    1194     logging.info('Calling model_fn.')
# -> 1195     model_fn_results = self._model_fn(features=features, **kwargs)
#    1196     logging.info('Done calling model_fn.')
#    1197
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in _model_fn(features, labels, mode, config)
#     484           config=config,
#     485           batch_norm=batch_norm,
# --> 486           shared_state_manager=shared_state_manager)
#     487
#     488     super(DNNClassifier, self).__init__(
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm, shared_state_manager)
#     298         batch_norm=batch_norm,
#     299         shared_state_manager=shared_state_manager)
# --> 300     logits = logit_fn(features=features, mode=mode)
#     301
#     302     if use_tpu:
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in dnn_logit_fn(features, mode)
#     107         shared_state_manager,
#     108         name='dnn')
# --> 109     return dnn_model(features, mode)
#     110
#     111   return dnn_logit_fn
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     755       if not in_deferred_mode:
#     756         self._in_call = True
# --> 757         outputs = self.call(inputs, *args, **kwargs)
#     758         self._in_call = False
#     759         if outputs is None:
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in call(self, features, mode)
#     202           'input_from_feature_columns',
#     203           partitioner=self._input_layer_partitioner):
# --> 204         net = self._input_layer(features)
#     205       for i in range(len(self._hidden_layers)):
#     206         net = self._hidden_layers[i](net)
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\feature_column\feature_column.py in __call__(self, features)
#     331         trainable=self._trainable,
#     332         cols_to_vars=None,
# --> 333         from_template=True)
#     334
#     335   @property
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\ops\template.py in __call__(self, *args, **kwargs)
#     366           custom_getter=self._custom_getter) as vs:
#     367         self._variable_scope = vs
# --> 368         return self._call_func(args, kwargs)
#     369
#     370   @property
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\ops\template.py in _call_func(self, args, kwargs)
#     309         # Checkpointable).
#     310         with checkpointable_util.capture_dependencies(template=self):
# --> 311           result = self._func(*args, **kwargs)
#     312
#     313       if self._variables_created:
#
# ~\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\feature_column\feature_column.py in _internal_input_layer(features, feature_columns, weight_collections, trainable, cols_to_vars, scope, cols_to_output_tensors, from_template)
#     181           'Items of feature_columns must be a _DenseColumn. '
#     182           'You can wrap a categorical column with an '
# --> 183           'embedding_column or indicator_column. Given: {}'.format(column))
#     184   weight_collections = list(weight_collections or [])
#     185   if ops.GraphKeys.GLOBAL_VARIABLES not in weight_collections:
#
# ValueError: Items of feature_columns must be a _DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: _VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)
#
# originally defined at:
#   File "C:\Users\Soroosh-PC\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\canned\dnn.py", line 108, in dnn_logit_fn
#     name='dnn')
#   File "C:\Users\Soroosh-PC\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\estimator\canned\dnn.py", line 143, in __init__
#     create_scope_now=False)
#   File "C:\Users\Soroosh-PC\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 323, in __init__
#     self._name, _internal_input_layer, create_scope_now_=create_scope_now)
#   File "C:\Users\Soroosh-PC\.conda\envs\KerasCPU\lib\site-packages\tensorflow\python\ops\template.py", line 154, in make_template
#     **kwargs)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\SOROOS~1\AppData\Local\Temp\tmpesx1m75r
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\SOROOS~1\\AppData\\Local\\Temp\\tmpesx1m75r', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000014C09C72E10>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\SOROOS~1\AppData\Local\Temp\tmpesx1m75r\model.ckpt.
# INFO:tensorflow:loss = 6.741715, step = 1
# INFO:tensorflow:global_step/sec: 262.613
# INFO:tensorflow:loss = 4.8117704, step = 101 (0.384 sec)
# INFO:tensorflow:global_step/sec: 393.93
# INFO:tensorflow:loss = 3.2300737, step = 201 (0.253 sec)
# INFO:tensorflow:global_step/sec: 403.456
# INFO:tensorflow:loss = 5.9111743, step = 301 (0.248 sec)
# INFO:tensorflow:global_step/sec: 410.072
# INFO:tensorflow:loss = 5.2346377, step = 401 (0.243 sec)
# INFO:tensorflow:global_step/sec: 377.574
# INFO:tensorflow:loss = 4.4067297, step = 501 (0.265 sec)
# INFO:tensorflow:global_step/sec: 365.172
# INFO:tensorflow:loss = 5.342113, step = 601 (0.276 sec)
# INFO:tensorflow:global_step/sec: 403.457
# INFO:tensorflow:loss = 4.648772, step = 701 (0.248 sec)
# INFO:tensorflow:global_step/sec: 406.737
# INFO:tensorflow:loss = 3.4351888, step = 801 (0.248 sec)
# INFO:tensorflow:global_step/sec: 401.837
# INFO:tensorflow:loss = 5.806636, step = 901 (0.248 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\SOROOS~1\AppData\Local\Temp\tmpesx1m75r\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.747509.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-21-18:24:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\SOROOS~1\AppData\Local\Temp\tmpesx1m75r\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-21-18:24:18
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7480315, accuracy_baseline = 0.65748036, auc = 0.81302917, auc_precision_recall = 0.66092587, average_loss = 0.51284647, global_step = 1000, label/mean = 0.34251967, loss = 5.0101156, precision = 0.64935064, prediction/mean = 0.3081809, recall = 0.57471263
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\SOROOS~1\AppData\Local\Temp\tmpesx1m75r\model.ckpt-1000
# {'accuracy': 0.7480315,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.81302917,
#  'auc_precision_recall': 0.66092587,
#  'average_loss': 0.51284647,
#  'label/mean': 0.34251967,
#  'loss': 5.0101156,
#  'precision': 0.64935064,
#  'prediction/mean': 0.3081809,
#  'recall': 0.57471263,
#  'global_step': 1000}
